# %% [markdown]
# ![logo_itq](img/logo-itq.jpeg)
# ## Maching Learning ,Variables Cualitativas
# *Nixon Malquin*

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
#Creao una variable de tipo lista vacia
nivel_estudios = []
#CReando o ingresando a mi lista la varaible Secuariada  y creo 110 veces secundarria
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Master' 'Master' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Secundaria' 'Master'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Grado' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Master' 'Secundaria' 'Grado'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Doctorado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Doctorado' 'Master' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Master' 'Grado' 'Doctorado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Doctorado' 'Secundaria' 'Bachillerato' 'Master'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Master' 'Grado' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Doctorado' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd

# Crear los datos
nivel_estudios = []

nivel_estudios.extend(['Secundaria'] * 110)
nivel_estudios.extend(['Bachillerato'] * 172)
nivel_estudios.extend(['Grado'] * 145)
nivel_estudios.extend(['Master'] * 52)
nivel_estudios.extend(['Doctorado'] * 21)

# Mezclar datos
nivel_estudios = np.random.permutation(nivel_estudios)

# Crear DataFrame
df = pd.DataFrame({
    'Nivel_Estudios': nivel_estudios
})

# Mostrar primeras filas
print(df.head())
# Out:
#   Nivel_Estudios
# 0   Bachillerato
# 1          Grado
# 2   Bachillerato
# 3     Secundaria
# 4      Doctorado

# %%
frecuencia = df['Nivel_Estudios'].value_counts()

print(frecuencia)
# Out:
# Nivel_Estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
frecuencia.plot(
    kind='bar',
    title='Nivel de Estudios',
    ylabel='Frecuencia',
    xlabel='Nivel de Estudios'
)

plt.show()

# %%
frecuencia.plot(
    kind='pie',
    autopct='%1.2f%%',
    title='Distribución de Nivel de Estudios'
)

plt.ylabel('')
plt.show()

# %% [markdown]
# Link de repositorio
#
# https://github.com/Ngmalquin123/MachingITQ
